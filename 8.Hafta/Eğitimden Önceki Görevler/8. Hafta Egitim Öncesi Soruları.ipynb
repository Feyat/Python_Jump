# %% [markdown]
# # Problem 1
# Kullanıcıdan aldığı ürün bilgisini (ad, fiyat) urunler.txt dosyasına kayıt eden fonksiyonu yazınız.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
def urunler(ad, fiyat):
    file = open('urunler.txt', 'a', encoding = 'utf-8')
    file.write(f'Ürün Adı: {ad}, fiyat: {fiyat}\n')
    file.close()

urunler('Armut', 25)
urunler('Domates', 35)
urunler('Elma', 34)

# %% [markdown]
# # Problem 2
# 1.problemde oluşturulan text dosyası içerisinde kullanıcıdan alacağımız eski kelime isimli değişkene atadığımız
# ve değiştirilmesini istediğimiz kelimemizi yerini alıcak olan yeni kelime isimli değişkene atayın. Belirlenen kelimeleri text dosyasında değiştiren fonksiyonu yazınız.

# %%
# 2.Problemin Çözümünü Buraya Yazınız

def değistir(eski, yeni):
    with open('urunler.txt', 'r+', encoding='utf-8') as file:
        veri = file.readlines()
        for a in veri:
            if eski in a:
                a = a.replace(eski, yeni)
            file.write(a)
değistir('Elma', 'Havuç')

# %%
def değistir(eski, yeni):
    with open('urunler.txt', 'r+', encoding='utf-8') as file:
        text = file.read()
        yeni_text = str(text.replace(eski, yeni))
        file.seek(0)
        text.write(yeni_text)
        text.truncate()
değistir('Domates', 'Havuç')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 8
#       6         text.write(yeni_text)
#       7         text.truncate()
# ----> 8 değistir('Domates', 'Havuç')
#
# Cell In[6], line 6, in değistir(eski, yeni)
#       4 yeni_text = str(text.replace(eski, yeni))
#       5 file.seek(0)
# ----> 6 text.write(yeni_text)
#       7 text.truncate()
#
# AttributeError: 'str' object has no attribute 'write'

# %% [markdown]
# # Problem 3
# Vehicle sınıfının tüm değişkenlerini ve yöntemlerini devralacak bir alt sınıf olarak Bus sınıfı oluşturunuz.
#
#
#
# ```
# Output
# > Name: School Volvo Speed: 180 Mileage: 12
# ```

# %%
# 3.Problemin Çözümünü Buraya Yazınız

class Vehicle():
    def __init__ (self, Name, Speed, Mileage):
        self.name = Name
        self.speed = Speed
        self.mileage = Mileage
a = Vehicle('School Volvo', 180, 12)

print(f'Name: {a.name } Speed: {a.speed } Mileage: {a.mileage} ')
# Out:
# Name: School Volvo Speed: 180 Mileage: 12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 11
#       8 a = Vehicle('School Volvo', 180, 12)
#      10 print(f'Name: {a.name } Speed: {a.speed } Mileage: {a.mileage} ')
# ---> 11 print(a())
#
# TypeError: 'Vehicle' object is not callable
